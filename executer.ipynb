# %%
f= open("funny.txt","r")

for line in f:
    print(line)
    f.close()
# Out:
# Teacher: Why are you late, raghu?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 f= open("funny.txt","r")
#       2
# ----> 3 for line in f:
#       4     print(line)
#       5     f.close()
#
# ValueError: I/O operation on closed file.

# %%
with open ("funny.txt",'r') as f:
    for line in f:
        print(line)
# Out:
# Teacher: Why are you late, raghu?
#
# Raghu: Because of the SIGN
#
# Teacher : what sign?
#
# Raghu: The one that says "school ahead, Go slow"

# %%
with open ("love.txt", "w") as f:
	f.write("I love python\n")
	f.write("I love Meditation")
# Out:
# <_io.TextIOWrapper name='love.txt' mode='w' encoding='cp1252'>

# %%
d = {
	'rohit' : [9]
	'sakib' : [50,34,20]

}

player_scores = {}
playear_scores = {
	'rohit': [9].append(score)
}

# %%
player_scores = {}
with open("scores.csv","r") as f:
	for line in f:
		player,match_id, score = line.split(',')
		score = int(score.strip())
		if player in player_scores:
			player_scores[player].append(score)
		else:
			player_scores[player] = [score]

# %%
player_scores
# Out:
# {'rohit': [9, 120, 105, 140, 130],
#  'shakib': [56, 78, 102, 72],
#  'babar': [56, 45, 120, 5, 67]}

# %%
for player, score_list in player_scores.items():
	min_score = min(score_list)
	max_score = max(score_list)
	avg_score = sum(score_list)/len(score_list)
	print(f"{player} ==> Min:{min_score},Max{max_score}, Avg:{avg_score}")
# Out:
# rohit ==> Min:9,Max140, Avg:100.8
# shakib ==> Min:56,Max102, Avg:77.0
# babar ==> Min:5,Max120, Avg:58.6
